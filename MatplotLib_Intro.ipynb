# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5,6,7]
y=[20,35,30,25,28,24,15]

# %%
plt.title('Weather')
plt.xlabel('Date')
plt.ylabel('Temperature')
plt.plot(x,y,color='red')
