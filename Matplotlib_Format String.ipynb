# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5,6,7]
y=[20,35,30,25,28,24,15]

# %%
#Markersize Property set size of marker while aplha Property shows transparency
plt.plot(x,y,'-gD',markersize=10,alpha=1)
